# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
purchase_data_df = purchase_data.copy()
purchase_data_df.head(20)
# Out:
#     Purchase ID             SN  Age                 Gender  Item ID  \
# 0             0        Lisim78   20                   Male      108
# 1             1    Lisovynya38   40                   Male      143
# 2             2     Ithergue48   24                   Male       92
# 3             3  Chamassasya86   24                   Male      100
# 4             4      Iskosia90   23                   Male      131
# 5             5        Yalae81   22                   Male       81
# 6             6      Itheria73   36                   Male      169
# 7             7    Iskjaskst81   20                   Male      162
# 8             8      Undjask33   22                   Male       21
# 9             9    Chanosian48   35  Other / Non-Disclosed      136
# 10           10      Inguron55   23                   Male       95
# 11           11   Haisrisuir60   23                   Male      162
# 12           12   Saelaephos52   21                   Male      116
# ...

# %%
#unique_players_df = pd.DataFrame(purchase_data_df["SN"].unique())
#player_count_series = unique_players_df.count()

#total_players_df = pd.DataFrame({"Total Players": player_count_series})

#total_players_df

#After initially writing the code above, i remembered the nunique function showed briefly in class
unique_players = purchase_data_df["SN"].nunique()

total_players_df = pd.DataFrame({"Total Players": [unique_players]})
total_players_df
# Out:
#    Total Players
# 0            576

# %%
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
number_of_items = purchase_data_df["Item Name"].nunique()
average_price = purchase_data_df["Price"].mean()
number_of_purchases = purchase_data_df["Purchase ID"].nunique()
total_revenue = purchase_data_df["Price"].sum()

purchasing_analysis_df = pd.DataFrame({"Number of Unique Items": [number_of_items],
                                       "Average Price": [average_price],
                                       "Number of Purchases": [number_of_purchases],
                                       "Total Revenue": [total_revenue],             
                                      })

purchasing_analysis_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179       3.050987                  780        2379.77

# %%
# Out:
#    Number of Unique Items Average Price Number of Purchases Total Revenue
# 0                     179         $3.05                 780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
group0_df=purchase_data_df.groupby(['SN']).count()
group0_df
# Out:
#                Purchase ID  Age  Gender  Item ID  Item Name  Price  Age Group
# SN
# Adairialis76             1    1       1        1          1      1          1
# Adastirin33              1    1       1        1          1      1          1
# Aeda94                   1    1       1        1          1      1          1
# Aela59                   1    1       1        1          1      1          1
# Aelaria33                1    1       1        1          1      1          1
# ...                    ...  ...     ...      ...        ...    ...        ...
# Yathecal82               3    3       3        3          3      3          3
# Yathedeu43               2    2       2        2          2      2          2
# Yoishirrala98            1    1       1        1          1      1          1
# Zhisrisu83               2    2       2        2          2      2          2
# Zontibe81                3    3       3        3          3      3          3
#
# [576 rows x 7 columns]

# %%
#no_dups_df=purchase_data_df.drop_duplicates(subset='SN', keep='first')
group1_df=purchase_data_df.groupby(['Gender','SN'])
group2_df = group_by_gender_df.count().groupby(['Gender'])
group3_df=group2_df[["Purchase ID"]].count().rename(columns={"Purchase ID": "Total Count"})
group3_df["Percentage of Players"]=group3_df["Total Count"]/group3_df["Total Count"].sum()
group_by_gender_distinct_df = group3_df.sort_values(["Total Count"], ascending = False)
group_by_gender_distinct_df
# Out:
#                        Total Count  Percentage of Players
# Gender
# Male                           484               0.840278
# Female                          81               0.140625
# Other / Non-Disclosed           11               0.019097

# %%
# Out:
#                        Total Count Percentage of Players
# Male                           484                84.03%
# Female                          81                14.06%
# Other / Non-Disclosed           11                 1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
grouped_by_gender1_df = purchase_data_df.groupby('Gender')
grouped_by_gender2_df = grouped_by_gender1_df.count()
group_by_gender_df = grouped_by_gender2_df[["Purchase ID"]].replace({"Purchase ID":"Purchase Count"})
group_by_gender_df
# Out:
#                        Purchase ID
# Gender
# Female                         113
# Male                           652
# Other / Non-Disclosed           15

# %%
grouped_by_gender1_df['Price'].sum()
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
grouped_by_gender1_df['Price'].mean()
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
group_by_gender_df["Average Purchase Price"]=grouped_by_gender1_df['Price'].mean().astype("float")
group_by_gender_df["Total Purchase Value"]=grouped_by_gender1_df['Price'].sum().astype("float")
group_by_gender_df["Person Count"]=group_by_gender_distinct_df[["Total Count"]].astype("float")
group_by_gender_df
# Out:
#                        Purchase ID  Average Purchase Price  \
# Gender
# Female                         113                3.203009
# Male                           652                3.017853
# Other / Non-Disclosed           15                3.346000
#
#                        Total Purchase Value  Person Count
# Gender
# Female                               361.94          81.0
# Male                                1967.64         484.0
# Other / Non-Disclosed                 50.19          11.0

# %%
group_by_gender_df["Avg per person"]=group_by_gender_df["Total Purchase Value"]/group_by_gender_df["Person Count"]

group_by_gender_df
# Out:
#                        Purchase ID  Average Purchase Price  \
# Gender
# Female                         113                3.203009
# Male                           652                3.017853
# Other / Non-Disclosed           15                3.346000
#
#                        Total Purchase Value  Person Count  Avg per person
# Gender
# Female                               361.94          81.0        4.468395
# Male                                1967.64         484.0        4.065372
# Other / Non-Disclosed                 50.19          11.0        4.562727

# %%
purchasing_analysis_gender_df=group_by_gender_df[["Purchase ID", "Average Purchase Price", "Total Purchase Value","Avg per person"]]
purchasing_analysis_gender_df
# Out:
#                        Purchase ID  Average Purchase Price  \
# Gender
# Female                         113                3.203009
# Male                           652                3.017853
# Other / Non-Disclosed           15                3.346000
#
#                        Total Purchase Value  Avg per person
# Gender
# Female                               361.94        4.468395
# Male                                1967.64        4.065372
# Other / Non-Disclosed                 50.19        4.562727

# %%
# Out:
#                       Purchase Count Average Purchase Price  \
# Gender
# Female                           113                  $3.20
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Creating Bins per the answer frame
#max_age=purchase_data_df["Age"].max()

bins = [0,9,14,19,24,29,34,39,200]

group_names = ["<10","10-14","15-19","20-24","25-29","30-34","34-39","40+"]
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                          Frenzied Scimitar   1.56       40+
# 2                               Final Critic   4.88     20-24
# 3                                Blindscythe   3.27     20-24
# 4                                       Fury   1.44     20-24

# %%
pd.cut(purchase_data_df["Age"], bins, labels=group_names, include_lowest=True)
# Out:
# 0      20-24
# 1        40+
# 2      20-24
# 3      20-24
# 4      20-24
#        ...
# 775    20-24
# 776    20-24
# 777    20-24
# 778      <10
# 779    20-24
# Name: Age, Length: 780, dtype: category
# Categories (8, object): ['<10' < '10-14' < '15-19' < '20-24' < '25-29' < '30-34' < '34-39' < '40+']

# %%
purchase_data_df["Age Group"] =pd.cut(purchase_data_df["Age"], bins, labels=group_names, include_lowest=True)
purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                            Frenzied Scimitar   1.56       40+
# 2                                 Final Critic   4.88     20-24
# ...

# %%
purchase_data_no_dups_df=purchase_data_df.drop_duplicates(subset='SN', keep='first')
purchase_data_no_dups_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 773          773         Hala31   21    Male       19
# 774          774     Jiskjask80   11    Male       92
# 775          775     Aethedru70   21  Female       60
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
#
#                                      Item Name  Price Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                            Frenzied Scimitar   1.56       40+
# 2                                 Final Critic   4.88     20-24
# ...

# %%
age_group=purchase_data_no_dups_df.groupby("Age Group")
age_demographics_df=age_group[['SN']].count().rename(columns={"SN":"Total Count"})
age_demographics_df["Percentage of Players"]=age_demographics_df["Total Count"]/age_demographics_df["Total Count"].sum()
age_demographics_df
# Out:
#            Total Count  Percentage of Players
# Age Group
# <10                 17               0.029514
# 10-14               22               0.038194
# 15-19              107               0.185764
# 20-24              258               0.447917
# 25-29               77               0.133681
# 30-34               52               0.090278
# 34-39               31               0.053819
# 40+                 12               0.020833

# %%
# Out:
#        Total Count Percentage of Players
# <10             17                 2.95%
# 10-14           22                 3.82%
# 15-19          107                18.58%
# 20-24          258                44.79%
# 25-29           77                13.37%
# 30-34           52                 9.03%
# 35-39           31                 5.38%
# 40+             12                 2.08%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Age bins created in prior section


purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                            Frenzied Scimitar   1.56       40+
# 2                                 Final Critic   4.88     20-24
# ...

# %%
age_group_purchase_0_df=purchase_data_df.groupby("Age Group")
age_group_purchase_df=age_group_purchase_0_df[['SN']].count().rename(columns={"SN":"Purchase Count"})

age_group_purchase_df
# Out:
#            Purchase Count
# Age Group
# <10                    23
# 10-14                  28
# 15-19                 136
# 20-24                 365
# 25-29                 101
# 30-34                  73
# 34-39                  41
# 40+                    13

# %%
age_group_purchase_df["Average Purchase Price"]=age_group_purchase_0_df['Price'].mean().astype("float")
age_group_purchase_df["Total Purchase Value"]=age_group_purchase_0_df['Price'].sum().astype("float")
age_group_purchase_df["Number of People"]=age_demographics_df[["Total Count"]].astype("float")
age_group_purchase_df["Avg Total Purchase per Person"]=age_group_purchase_df["Total Purchase Value"]/age_group_purchase_df["Number of People"]
age_group_purchase_df
# Out:
#            Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Group
# <10                    23                3.353478                 77.13
# 10-14                  28                2.956429                 82.78
# 15-19                 136                3.035956                412.89
# 20-24                 365                3.052219               1114.06
# 25-29                 101                2.900990                293.00
# 30-34                  73                2.931507                214.00
# 34-39                  41                3.601707                147.67
# 40+                    13                2.941538                 38.24
#
#            Number of People  Avg Total Purchase per Person
# Age Group
# <10                    17.0                       4.537059
# 10-14                  22.0                       3.762727
# 15-19                 107.0                       3.858785
# 20-24                 258.0                       4.318062
# ...

# %%
purchasing_analysis_age_group_df=age_group_purchase_df[["Purchase Count", "Average Purchase Price", "Total Purchase Value","Avg Total Purchase per Person"]]
purchasing_analysis_age_group_df
# Out:
#            Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Group
# <10                    23                3.353478                 77.13
# 10-14                  28                2.956429                 82.78
# 15-19                 136                3.035956                412.89
# 20-24                 365                3.052219               1114.06
# 25-29                 101                2.900990                293.00
# 30-34                  73                2.931507                214.00
# 34-39                  41                3.601707                147.67
# 40+                    13                2.941538                 38.24
#
#            Avg Total Purchase per Person
# Age Group
# <10                             4.537059
# 10-14                           3.762727
# 15-19                           3.858785
# 20-24                           4.318062
# 25-29                           3.805195
# 30-34                           4.115385
# ...

# %%
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05            $1,114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
purchase_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                            Frenzied Scimitar   1.56       40+
# 2                                 Final Critic   4.88     20-24
# ...

# %%
Lisosia93_df = purchase_data_df.loc[purchase_data_df["SN"] == "Lisosia93", :]
Lisosia93_count=Lisosia93_df['SN'].count()
Lisosia93_price=Lisosia93_df['Price'].mean()
Lisosia93_total=Lisosia93_df['Price'].sum()

# %%
Idastidru52_df = purchase_data_df.loc[purchase_data_df["SN"] == "Idastidru52", :]
Idastidru52_count=Idastidru52_df['SN'].count()
Idastidru52_price=Idastidru52_df['Price'].mean()
Idastidru52_total=Idastidru52_df['Price'].sum()

# %%
Chamjask73_df = purchase_data_df.loc[purchase_data_df["SN"] == "Chamjask73", :]
Chamjask73_count=Chamjask73_df['SN'].count()
Chamjask73_price=Chamjask73_df['Price'].mean()
Chamjask73_total=Chamjask73_df['Price'].sum()

# %%
Iral74_df = purchase_data_df.loc[purchase_data_df["SN"] == "Iral74", :]
Iral74_count=Iral74_df['SN'].count()
Iral74_price=Iral74_df['Price'].mean()
Iral74_total=Iral74_df['Price'].sum()

# %%
Iskadarya95_df = purchase_data_df.loc[purchase_data_df["SN"] == "Iskadarya95", :]
Iskadarya95_count=Iskadarya95_df['SN'].count()
Iskadarya95_price=Iskadarya95_df['Price'].mean()
Iskadarya95_total=Iskadarya95_df['Price'].sum()

# %%
summary_df = pd.DataFrame({"SN":["Lisosia93","Idastidru52","Chamjask73","Iral74","Iskadarya95"],
                            "Purchase Count":[Lisosia93_count,Idastidru52_count,Chamjask73_count,Iral74_count,Iskadarya95_count],
                            "Average Purchase Price":[Lisosia93_price,Idastidru52_price,Chamjask73_price,Iral74_price,Iskadarya95_price],
                            "Total Purchase Value":[Lisosia93_total,Idastidru52_total,Chamjask73_total,Iral74_total,Iskadarya95_total]
                          }
                         )



summary_df
# Out:
#             SN  Purchase Count  Average Purchase Price  Total Purchase Value
# 0    Lisosia93               5                3.792000                 18.96
# 1  Idastidru52               4                3.862500                 15.45
# 2   Chamjask73               3                4.610000                 13.83
# 3       Iral74               4                3.405000                 13.62
# 4  Iskadarya95               3                4.366667                 13.10

# %%
summary_new_index_df = summary_df.set_index("SN")
summary_new_index_df
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10

# %%
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
popular_0_df=purchase_data_df[["Item ID","Item Name","Price"]]
#popular_0_df

# %%
popular_grouped=popular_0_df.groupby(["Item ID","Item Name"])
popular_grouped_df=popular_grouped[['Price']].count().rename(columns={"Price":"Purchase Count"})
#popular_grouped_df

# %%
popular_grouped_df["Item Price"]=popular_grouped['Price'].mean().astype("float")
popular_grouped_df["Total Purchase Value"]=popular_grouped['Price'].sum().astype("float")                   
                
popular_grouped_df
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 0       Splinter                                                   4
# 1       Crucifer                                                   4
# 2       Verdict                                                    6
# 3       Phantomlight                                               6
# 4       Bloodlord's Fetish                                         5
# ...                                                              ...
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 179     Wolf, Promise of the Moonwalker                            6
# 181     Reaper's Toll                                              5
# 182     Toothpick                                                  3
# 183     Dragon's Greatsword                                        3
#
#                                                       Item Price  \
# Item ID Item Name
# ...

# %%
popular_grouped_sorted_df = popular_grouped_df.sort_values(["Purchase Count"], ascending = False)
popular_grouped_sorted_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 145     Fiery Glass Crusader                            4.580000
# 132     Persuasion                                      3.221111
# 108     Extraction, Quickblade Of Trembling Hands       3.530000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 132     Persuasion                                                9
# 108     Extraction, Quickblade Of Trembling Hands                 9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
most_profitable_df = popular_grouped_df.sort_values(["Total Purchase Value"], ascending = False)
most_profitable_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 82      Nirvana                                         4.900000
# 145     Fiery Glass Crusader                            4.580000
# 103     Singed Scalpel                                  4.350000
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# ...
